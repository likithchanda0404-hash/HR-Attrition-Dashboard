# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("../data/HR_Employee_Attrition.csv")

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                       0                     5
# 1                   7                       1                     7
# 2                   0                       0                     0
# 3                   7                       3                     0
# 4                   2                       2                     2
#
# [5 rows x 30 columns]

# %%
df.shape
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                       0                     5
# 1                   7                       1                     7
# 2                   0                       0                     0
# 3                   7                       3                     0
# 4                   2                       2                     2
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       25 non-null     int64
#  1   Attrition                 25 non-null     object
#  2   BusinessTravel            25 non-null     object
#  3   DailyRate                 25 non-null     int64
#  4   Department                25 non-null     object
#  5   DistanceFromHome          25 non-null     int64
#  6   Education                 25 non-null     int64
#  7   EducationField            25 non-null     object
#  8   EnvironmentSatisfaction   25 non-null     int64
#  9   Gender                    25 non-null     object
#  10  HourlyRate                25 non-null     int64
#  11  JobInvolvement            25 non-null     int64
#  12  JobLevel                  25 non-null     int64
#  13  JobRole                   25 non-null     object
#  14  JobSatisfaction           25 non-null     int64
#  15  MaritalStatus             25 non-null     object
#  16  MonthlyIncome             25 non-null     int64
#  17  NumCompaniesWorked        25 non-null     int64
#  18  OverTime                  25 non-null     object
#  19  PercentSalaryHike         25 non-null     int64
#  20  PerformanceRating         25 non-null     int64
#  21  RelationshipSatisfaction  25 non-null     int64
#  22  StockOptionLevel          25 non-null     int64
#  23  TotalWorkingYears         25 non-null     int64
#  24  TrainingTimesLastYear     25 non-null     int64
#  25  WorkLifeBalance           25 non-null     int64
#  26  YearsAtCompany            25 non-null     int64
#  27  YearsInCurrentRole        25 non-null     int64
#  28  YearsSinceLastPromotion   25 non-null     int64
#  29  YearsWithCurrManager      25 non-null     int64
# dtypes: int64(22), object(8)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#              Age    DailyRate  DistanceFromHome  Education  \
# count  25.000000    25.000000         25.000000  25.000000
# mean   34.600000   855.840000         11.560000   2.520000
# std     8.878814   464.072882          8.953956   1.004988
# min    21.000000   103.000000          1.000000   1.000000
# 25%    29.000000   391.000000          3.000000   2.000000
# 50%    34.000000  1005.000000          9.000000   2.000000
# 75%    37.000000  1299.000000         19.000000   3.000000
# max    59.000000  1392.000000         27.000000   4.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement   JobLevel  \
# count                25.000000   25.000000       25.000000  25.000000
# mean                  2.640000   71.000000        2.960000   1.520000
# std                   1.220656   20.958292        0.734847   0.822598
# min                   1.000000   31.000000        2.000000   1.000000
# 25%                   1.000000   51.000000        2.000000   1.000000
# 50%                   3.000000   79.000000        3.000000   1.000000
# 75%                   4.000000   92.000000        3.000000   2.000000
# max                   4.000000   96.000000        4.000000   4.000000
#
#        JobSatisfaction  MonthlyIncome  ...  PerformanceRating  \
# count        25.000000      25.000000  ...          25.000000
# mean          2.880000    4406.840000  ...           3.200000
# std           0.881287    3115.727024  ...           0.408248
# min           1.000000    1232.000000  ...           3.000000
# 25%           2.000000    2693.000000  ...           3.000000
# 50%           3.000000    3298.000000  ...           3.000000
# 75%           3.000000    5130.000000  ...           3.000000
# max           4.000000   15427.000000  ...           4.000000
#
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count                 25.000000         25.000000          25.000000
# mean                   2.880000          0.760000           8.800000
# std                    0.971253          0.879394           6.191392
# min                    1.000000          0.000000           1.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000           8.000000
# 75%                    4.000000          1.000000          10.000000
# max                    4.000000          3.000000          31.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count              25.000000        25.000000       25.000000
# mean                2.720000         2.680000        6.360000
# std                 1.137248         0.556776        5.438137
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        2.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 5.000000         3.000000       25.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count           25.000000                25.000000             25.000000
# mean             4.040000                 1.840000              4.320000
# std              3.142186                 2.392349              3.590729
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             11.000000                 8.000000             13.000000
#
# [8 rows x 22 columns]

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     20
# Yes     5
# Name: count, dtype: int64

# %%
sns.countplot(x="Attrition", data=df)
plt.title("Attrition Count")
plt.show()

# %%
sns.countplot(x="Department", hue="Attrition", data=df)
plt.title("Attrition by Department")
plt.xticks(rotation=30)
plt.show()

# %%
sns.boxplot(x="Attrition", y="MonthlyIncome", data=df)
plt.title("Attrition vs Monthly Income")
plt.show()

# %%
sns.countplot(x="OverTime", hue="Attrition", data=df)
plt.title("Attrition vs Overtime")
plt.show()

# %%
sns.histplot(data=df, x="Age", hue="Attrition", kde=True)
plt.title("Attrition by Age")
plt.show()

# %%
df.to_csv("../data/cleaned_hr_attrition.csv", index=False)
